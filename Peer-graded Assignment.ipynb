# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tanasa Alida Cristina**
#
# Data scientist

# %% [markdown]
# *I am interested in data science because I believe that from data, one can extract a lot of powerfull information.*

# %% [markdown]
# ### The code below will calculate the sum between 2 variables

# %%
def sum(a,b):
    rez = a+b
    return rez

sum(1,2)
# Out:
# 3

# %% [markdown]
# ***
# + One
# - Two
# * Three
# 1. Data
# 2. Science
